# %%
# !pip3 install torchrl
# !pip3 install vmas
# !pip3 install tqdm
# Out:
# Requirement already satisfied: torchrl in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (0.9.2)
# Requirement already satisfied: torch>=2.1.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torchrl) (2.8.0)
# Requirement already satisfied: numpy in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torchrl) (1.24.0)
# Requirement already satisfied: packaging in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torchrl) (25.0)
# Requirement already satisfied: cloudpickle in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torchrl) (3.1.1)
# Requirement already satisfied: tensordict<0.10.0,>=0.9.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torchrl) (0.9.1)
# Requirement already satisfied: importlib_metadata in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from tensordict<0.10.0,>=0.9.0->torchrl) (8.7.0)
# Requirement already satisfied: orjson in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from tensordict<0.10.0,>=0.9.0->torchrl) (3.11.3)
# Requirement already satisfied: pyvers<0.2.0,>=0.1.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from tensordict<0.10.0,>=0.9.0->torchrl) (0.1.0)
# Requirement already satisfied: filelock in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (1.13.3)
# Requirement already satisfied: networkx in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (3.4.2)
# Requirement already satisfied: jinja2 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (3.1.6)
# Requirement already satisfied: fsspec in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch>=2.1.0->torchrl) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from triton==3.4.0->torch>=2.1.0->torchrl) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.1.0->torchrl) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from importlib_metadata->tensordict<0.10.0,>=0.9.0->torchrl) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->torchrl) (3.0.2)
# Collecting vmas
#   Downloading vmas-1.5.0.tar.gz (217 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from vmas) (1.24.0)
# Requirement already satisfied: torch in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from vmas) (2.8.0)
# Collecting pyglet<=1.5.27 (from vmas)
#   Downloading pyglet-1.5.27-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: gym in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from vmas) (0.26.2)
# Requirement already satisfied: six in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from vmas) (1.17.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from gym->vmas) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from gym->vmas) (0.1.0)
# Requirement already satisfied: filelock in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (1.13.3)
# Requirement already satisfied: networkx in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (3.4.2)
# Requirement already satisfied: jinja2 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (3.1.6)
# Requirement already satisfied: fsspec in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from torch->vmas) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from triton==3.4.0->torch->vmas) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from sympy>=1.13.3->torch->vmas) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (from jinja2->torch->vmas) (3.0.2)
# Downloading pyglet-1.5.27-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.2 MB/s eta 0:00:00
# Building wheels for collected packages: vmas
#   DEPRECATION: Building 'vmas' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'vmas'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for vmas (setup.py) ... done
#   Created wheel for vmas: filename=vmas-1.5.0-py3-none-any.whl size=257607 sha256=081c60980e39915a51279798b77968ff94f69b3d30a879b1958e46e908dc4b37
#   Stored in directory: /home/thickhoctin/.cache/pip/wheels/c1/ca/d8/e1b2b0bb740ad9ce165b19e2a368c586be4210a8c2a2867e43
# Successfully built vmas
# Installing collected packages: pyglet, vmas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [vmas]t]
# Successfully installed pyglet-1.5.27 vmas-1.5.0
# Requirement already satisfied: tqdm in /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages (4.67.1)

# %%
# Torch
import torch

# Tensordict modules
from tensordict.nn import set_composite_lp_aggregate, TensorDictModule
from tensordict.nn.distributions import NormalParamExtractor
from torch import multiprocessing

# Data collection
from torchrl.collectors import SyncDataCollector
from torchrl.data.replay_buffers import ReplayBuffer
from torchrl.data.replay_buffers.samplers import SamplerWithoutReplacement
from torchrl.data.replay_buffers.storages import LazyTensorStorage

# Env
from torchrl.envs import RewardSum, TransformedEnv
from torchrl.envs.libs.vmas import VmasEnv
from torchrl.envs.utils import check_env_specs

# Multi-agent network
from torchrl.modules import MultiAgentMLP, ProbabilisticActor, TanhNormal

# Loss
from torchrl.objectives import ClipPPOLoss, ValueEstimators

# Utils
torch.manual_seed(0)
from matplotlib import pyplot as plt
from tqdm import tqdm
# Out:
# /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
# Devices
is_fork = multiprocessing.get_start_method() == "fork"
device = (
    torch.device(0)
    if torch.cuda.is_available() and not is_fork
    else torch.device("cpu")
)
vmas_device = device  # The device where the simulator is run (VMAS can run on GPU)

# Sampling
frames_per_batch = 6_000  # Number of team frames collected per training iteration
n_iters = 5  # Number of sampling and training iterations
total_frames = frames_per_batch * n_iters

# Training
num_epochs = 30  # Number of optimization steps per training iteration
minibatch_size = 400  # Size of the mini-batches in each optimization step
lr = 3e-4  # Learning rate
max_grad_norm = 1.0  # Maximum norm for the gradients

# PPO
clip_epsilon = 0.2  # clip value for PPO loss
gamma = 0.99  # discount factor
lmbda = 0.9  # lambda for generalised advantage estimation
entropy_eps = 1e-4  # coefficient of the entropy term in the PPO loss

# disable log-prob aggregation
set_composite_lp_aggregate(False).set()

# %%
max_steps = 100  # Episode steps before done
num_vmas_envs = (
    frames_per_batch // max_steps
)  # Number of vectorized envs. frames_per_batch should be divisible by this number
scenario_name = "navigation"
n_agents = 3

env = VmasEnv(
    scenario=scenario_name,
    num_envs=num_vmas_envs,
    continuous_actions=True,  # VMAS supports both continuous and discrete actions
    max_steps=max_steps,
    device=vmas_device,
    # Scenario kwargs
    n_agents=n_agents,  # These are custom kwargs that change for each VMAS scenario, see the VMAS repo to know more.
)
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
print("action_spec:", env.full_action_spec)
print("reward_spec:", env.full_reward_spec)
print("done_spec:", env.full_done_spec)
print("observation_spec:", env.observation_spec)
# Out:
# action_spec: Composite(
#     agents: Composite(
#         action: BoundedContinuous(
#             shape=torch.Size([60, 3, 2]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([60, 3, 2]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([60, 3, 2]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([60, 3]),
#         data_cls=None),
#     device=cuda:0,
#     shape=torch.Size([60]),
#     data_cls=None)
# reward_spec: Composite(
#     agents: Composite(
#         reward: UnboundedContinuous(
#             shape=torch.Size([60, 3, 1]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         device=cuda:0,
#         shape=torch.Size([60, 3]),
#         data_cls=None),
#     device=cuda:0,
#     shape=torch.Size([60]),
#     data_cls=None)
# done_spec: Composite(
#     done: Categorical(
#         shape=torch.Size([60, 1]),
#         space=CategoricalBox(n=2),
#         device=cuda:0,
#         dtype=torch.bool,
#         domain=discrete),
#     terminated: Categorical(
#         shape=torch.Size([60, 1]),
#         space=CategoricalBox(n=2),
#         device=cuda:0,
#         dtype=torch.bool,
#         domain=discrete),
#     device=cuda:0,
#     shape=torch.Size([60]),
#     data_cls=None)
# observation_spec: Composite(
#     agents: Composite(
#         observation: UnboundedContinuous(
#             shape=torch.Size([60, 3, 18]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([60, 3, 18]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([60, 3, 18]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#             device=cuda:0,
#             dtype=torch.float32,
#             domain=continuous),
#         info: Composite(
#             pos_rew: UnboundedContinuous(
#                 shape=torch.Size([60, 3, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             final_rew: UnboundedContinuous(
#                 shape=torch.Size([60, 3, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             agent_collisions: UnboundedContinuous(
#                 shape=torch.Size([60, 3, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, contiguous=True)),
#                 device=cuda:0,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cuda:0,
#             shape=torch.Size([60, 3]),
#             data_cls=None),
#         device=cuda:0,
#         shape=torch.Size([60, 3]),
#         data_cls=None),
#     device=cuda:0,
#     shape=torch.Size([60]),
#     data_cls=None)

# %%
print("action_keys:", env.action_keys)
print("reward_keys:", env.reward_keys)
print("done_keys:", env.done_keys)
# Out:
# action_keys: [('agents', 'action')]
# reward_keys: [('agents', 'reward')]
# done_keys: ['done', 'terminated']

# %%
env = TransformedEnv(
    env,
    RewardSum(in_keys=[env.reward_key], out_keys=[("agents", "episode_reward")]),
)

# %%
check_env_specs(env)
# Out:
# 2025-09-13 23:59:43,697 [torchrl][INFO]    check_env_specs succeeded! [END]

# %%
n_rollout_steps = 5
rollout = env.rollout(n_rollout_steps)
print("rollout of three steps:", rollout)
print("Shape of the rollout TensorDict:", rollout.batch_size)
# Out:
# rollout of three steps: TensorDict(
#     fields={
#         agents: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([60, 5, 3, 2]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 episode_reward: Tensor(shape=torch.Size([60, 5, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 info: TensorDict(
#                     fields={
#                         agent_collisions: Tensor(shape=torch.Size([60, 5, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                         final_rew: Tensor(shape=torch.Size([60, 5, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                         pos_rew: Tensor(shape=torch.Size([60, 5, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True)},
#                     batch_size=torch.Size([60, 5, 3]),
#                     device=cuda:0,
#                     is_shared=True),
#                 observation: Tensor(shape=torch.Size([60, 5, 3, 18]), device=cuda:0, dtype=torch.float32, is_shared=True)},
#             batch_size=torch.Size([60, 5, 3]),
#             device=cuda:0,
#             is_shared=True),
#         done: Tensor(shape=torch.Size([60, 5, 1]), device=cuda:0, dtype=torch.bool, is_shared=True),
#         next: TensorDict(
#             fields={
#                 agents: TensorDict(
#                     fields={
#                         episode_reward: Tensor(shape=torch.Size([60, 5, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                         info: TensorDict(
#                             fields={
#                                 agent_collisions: Tensor(shape=torch.Size([60, 5, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                                 final_rew: Tensor(shape=torch.Size([60, 5, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                                 pos_rew: Tensor(shape=torch.Size([60, 5, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True)},
#                             batch_size=torch.Size([60, 5, 3]),
#                             device=cuda:0,
#                             is_shared=True),
#                         observation: Tensor(shape=torch.Size([60, 5, 3, 18]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                         reward: Tensor(shape=torch.Size([60, 5, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True)},
#                     batch_size=torch.Size([60, 5, 3]),
#                     device=cuda:0,
#                     is_shared=True),
#                 done: Tensor(shape=torch.Size([60, 5, 1]), device=cuda:0, dtype=torch.bool, is_shared=True),
#                 terminated: Tensor(shape=torch.Size([60, 5, 1]), device=cuda:0, dtype=torch.bool, is_shared=True)},
#             batch_size=torch.Size([60, 5]),
#             device=cuda:0,
#             is_shared=True),
#         terminated: Tensor(shape=torch.Size([60, 5, 1]), device=cuda:0, dtype=torch.bool, is_shared=True)},
#     batch_size=torch.Size([60, 5]),
#     device=cuda:0,
#     is_shared=True)
# Shape of the rollout TensorDict: torch.Size([60, 5])

# %%
share_parameters_policy = True

policy_net = torch.nn.Sequential(
    MultiAgentMLP(
        n_agent_inputs=env.observation_spec["agents", "observation"].shape[
            -1
        ],  # n_obs_per_agent
        n_agent_outputs=2
        * env.full_action_spec[env.action_key].shape[-1],  # 2 * n_actions_per_agents
        n_agents=env.n_agents,
        centralised=False,  # the policies are decentralised (ie each agent will act from its observation)
        share_params=share_parameters_policy,
        device=device,
        depth=2,
        num_cells=256,
        activation_class=torch.nn.Tanh,
    ),
    NormalParamExtractor(),  # this will just separate the last dimension into two outputs: a loc and a non-negative scale
)

# %%
policy_module = TensorDictModule(
    policy_net,
    in_keys=[("agents", "observation")],
    out_keys=[("agents", "loc"), ("agents", "scale")],
)

# %%
policy = ProbabilisticActor(
    module=policy_module,
    spec=env.action_spec_unbatched,
    in_keys=[("agents", "loc"), ("agents", "scale")],
    out_keys=[env.action_key],
    distribution_class=TanhNormal,
    distribution_kwargs={
        "low": env.full_action_spec_unbatched[env.action_key].space.low,
        "high": env.full_action_spec_unbatched[env.action_key].space.high,
    },
    return_log_prob=True,
)  # we'll need the log-prob for the PPO loss

# %%
share_parameters_critic = True
mappo = True  # IPPO if False

critic_net = MultiAgentMLP(
    n_agent_inputs=env.observation_spec["agents", "observation"].shape[-1],
    n_agent_outputs=1,  # 1 value per agent
    n_agents=env.n_agents,
    centralised=mappo,
    share_params=share_parameters_critic,
    device=device,
    depth=2,
    num_cells=256,
    activation_class=torch.nn.Tanh,
)

critic = TensorDictModule(
    module=critic_net,
    in_keys=[("agents", "observation")],
    out_keys=[("agents", "state_value")],
)

# %%
print("Running policy:", policy(env.reset()))
print("Running value:", critic(env.reset()))
# Out:
# Running policy: TensorDict(
#     fields={
#         agents: TensorDict(
#             fields={
#                 action: Tensor(shape=torch.Size([60, 3, 2]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 action_log_prob: Tensor(shape=torch.Size([60, 3]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 episode_reward: Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 info: TensorDict(
#                     fields={
#                         agent_collisions: Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                         final_rew: Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                         pos_rew: Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True)},
#                     batch_size=torch.Size([60, 3]),
#                     device=cuda:0,
#                     is_shared=True),
#                 loc: Tensor(shape=torch.Size([60, 3, 2]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 observation: Tensor(shape=torch.Size([60, 3, 18]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 scale: Tensor(shape=torch.Size([60, 3, 2]), device=cuda:0, dtype=torch.float32, is_shared=True)},
#             batch_size=torch.Size([60, 3]),
#             device=cuda:0,
#             is_shared=True),
#         done: Tensor(shape=torch.Size([60, 1]), device=cuda:0, dtype=torch.bool, is_shared=True),
#         terminated: Tensor(shape=torch.Size([60, 1]), device=cuda:0, dtype=torch.bool, is_shared=True)},
#     batch_size=torch.Size([60]),
#     device=cuda:0,
#     is_shared=True)
# Running value: TensorDict(
#     fields={
#         agents: TensorDict(
#             fields={
#                 episode_reward: Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 info: TensorDict(
#                     fields={
#                         agent_collisions: Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                         final_rew: Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                         pos_rew: Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True)},
#                     batch_size=torch.Size([60, 3]),
#                     device=cuda:0,
#                     is_shared=True),
#                 observation: Tensor(shape=torch.Size([60, 3, 18]), device=cuda:0, dtype=torch.float32, is_shared=True),
#                 state_value: Tensor(shape=torch.Size([60, 3, 1]), device=cuda:0, dtype=torch.float32, is_shared=True)},
#             batch_size=torch.Size([60, 3]),
#             device=cuda:0,
#             is_shared=True),
#         done: Tensor(shape=torch.Size([60, 1]), device=cuda:0, dtype=torch.bool, is_shared=True),
#         terminated: Tensor(shape=torch.Size([60, 1]), device=cuda:0, dtype=torch.bool, is_shared=True)},
#     batch_size=torch.Size([60]),
#     device=cuda:0,
#     is_shared=True)

# %%
collector = SyncDataCollector(
    env,
    policy,
    device=vmas_device,
    storing_device=device,
    frames_per_batch=frames_per_batch,
    total_frames=total_frames,
)

# %%
replay_buffer = ReplayBuffer(
    storage=LazyTensorStorage(
        frames_per_batch, device=device
    ),  # We store the frames_per_batch collected at each iteration
    sampler=SamplerWithoutReplacement(),
    batch_size=minibatch_size,  # We will sample minibatches of this size
)

# %%
loss_module = ClipPPOLoss(
    actor_network=policy,
    critic_network=critic,
    clip_epsilon=clip_epsilon,
    entropy_coef=entropy_eps,
    normalize_advantage=False,  # Important to avoid normalizing across the agent dimension
)
loss_module.set_keys(  # We have to tell the loss where to find the keys
    reward=env.reward_key,
    action=env.action_key,
    value=("agents", "state_value"),
    # These last 2 keys will be expanded to match the reward shape
    done=("agents", "done"),
    terminated=("agents", "terminated"),
)


loss_module.make_value_estimator(
    ValueEstimators.GAE, gamma=gamma, lmbda=lmbda
)  # We build GAE
GAE = loss_module.value_estimator

optim = torch.optim.Adam(loss_module.parameters(), lr)
# Out:
# /home/thickhoctin/miniconda3/envs/thesis_env/lib/python3.10/site-packages/torchrl/objectives/ppo.py:450: DeprecationWarning: 'entropy_coef' is deprecated and will be removed in torchrl v0.11. Please use 'entropy_coeff' instead.
#   warnings.warn(

# %%
pbar = tqdm(total=n_iters, desc="episode_reward_mean = 0")

episode_reward_mean_list = []
for tensordict_data in collector:
    tensordict_data.set(
        ("next", "agents", "done"),
        tensordict_data.get(("next", "done"))
        .unsqueeze(-1)
        .expand(tensordict_data.get_item_shape(("next", env.reward_key))),
    )
    tensordict_data.set(
        ("next", "agents", "terminated"),
        tensordict_data.get(("next", "terminated"))
        .unsqueeze(-1)
        .expand(tensordict_data.get_item_shape(("next", env.reward_key))),
    )
    # We need to expand the done and terminated to match the reward shape (this is expected by the value estimator)

    with torch.no_grad():
        GAE(
            tensordict_data,
            params=loss_module.critic_network_params,
            target_params=loss_module.target_critic_network_params,
        )  # Compute GAE and add it to the data

    data_view = tensordict_data.reshape(-1)  # Flatten the batch size to shuffle data
    replay_buffer.extend(data_view)

    for _ in range(num_epochs):
        for _ in range(frames_per_batch // minibatch_size):
            subdata = replay_buffer.sample()
            loss_vals = loss_module(subdata)

            loss_value = (
                loss_vals["loss_objective"]
                + loss_vals["loss_critic"]
                + loss_vals["loss_entropy"]
            )

            loss_value.backward()

            torch.nn.utils.clip_grad_norm_(
                loss_module.parameters(), max_grad_norm
            )  # Optional

            optim.step()
            optim.zero_grad()

    collector.update_policy_weights_()

    # Logging
    done = tensordict_data.get(("next", "agents", "done"))
    episode_reward_mean = (
        tensordict_data.get(("next", "agents", "episode_reward"))[done].mean().item()
    )
    episode_reward_mean_list.append(episode_reward_mean)
    pbar.set_description(f"episode_reward_mean = {episode_reward_mean}", refresh=False)
    pbar.update()
# Out:
# episode_reward_mean = 1.8292104005813599: 100%|██████████| 5/5 [00:20<00:00,  4.01s/it]

# %%
plt.plot(episode_reward_mean_list)
plt.xlabel("Training iterations")
plt.ylabel("Reward")
plt.title("Episode reward mean")
plt.show()

# %%
with torch.no_grad():
   env.rollout(
       max_steps=max_steps,
       policy=policy,
       callback=lambda env, _: env.render(),
       auto_cast_to_device=True,
       break_when_any_done=False,
   )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 with torch.no_grad():
# ----> 2    env.rollout(
#       3        max_steps=max_steps,
#       4        policy=policy,
#       5        callback=lambda env, _: env.render(),
#       6        auto_cast_to_device=True,
#       7        break_when_any_done=False,
#       8    )
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/torchrl/envs/common.py:3383, in EnvBase.rollout(self, max_steps, policy, callback, auto_reset, auto_cast_to_device, break_when_any_done, break_when_all_done, return_contiguous, tensordict, set_truncated, out, trust_policy)
#    3377     tensordicts = self._rollout_stop_early(
#    3378         break_when_all_done=break_when_all_done,
#    3379         break_when_any_done=break_when_any_done,
#    3380         **kwargs,
#    3381     )
#    3382 else:
# -> 3383     tensordicts = self._rollout_nonstop(**kwargs)
#    3384 batch_size = self.batch_size if tensordict is None else tensordict.batch_size
#    3385 if return_contiguous:
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/torchrl/envs/common.py:3607, in EnvBase._rollout_nonstop(self, tensordict, auto_cast_to_device, max_steps, policy, policy_device, env_device, callback)
#    3605         break
#    3606     if callback is not None:
# -> 3607         callback(self, tensordict)
#    3609 return tensordicts
#
# Cell In[21], line 5, in <lambda>(env, _)
#       1 with torch.no_grad():
#       2    env.rollout(
#       3        max_steps=max_steps,
#       4        policy=policy,
# ----> 5        callback=lambda env, _: env.render(),
#       6        auto_cast_to_device=True,
#       7        break_when_any_done=False,
#       8    )
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/vmas/simulator/environment/environment.py:706, in Environment.render(self, mode, env_index, agent_index_focus, visualize_when_rgb, plot_position_function, plot_position_function_precision, plot_position_function_range, plot_position_function_cmap_range, plot_position_function_cmap_alpha, plot_position_function_cmap_name)
#     703         self.headless = False
#     704     pyglet.options["headless"] = self.headless
# --> 706     self._init_rendering()
#     708 if self.scenario.viewer_zoom <= 0:
#     709     raise ValueError("Scenario viewer zoom must be > 0")
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/vmas/simulator/environment/environment.py:879, in Environment._init_rendering(self)
#     878 def _init_rendering(self):
# --> 879     from vmas.simulator import rendering
#     881     self.viewer = rendering.Viewer(
#     882         *self.scenario.viewer_size, visible=self.visible_display
#     883     )
#     885     self.text_lines = []
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/vmas/simulator/rendering.py:25
#      22 from vmas.simulator.utils import TorchUtils, x_to_rgb_colormap
#      24 try:
# ---> 25     from pyglet.gl import (
#      26         GL_BLEND,
#      27         GL_LINE_LOOP,
#      28         GL_LINE_SMOOTH,
#      29         GL_LINE_SMOOTH_HINT,
#      30         GL_LINE_STIPPLE,
#      31         GL_LINE_STRIP,
#      32         GL_LINES,
#      33         GL_NICEST,
#      34         GL_ONE_MINUS_SRC_ALPHA,
#      35         GL_POINTS,
#      36         GL_POLYGON,
#      37         GL_QUADS,
#      38         GL_SRC_ALPHA,
#      39         GL_TRIANGLES,
#      40         glBegin,
#      41         glBlendFunc,
#      42         glClearColor,
#      43         glColor4f,
#      44         glDisable,
#      45         glEnable,
#      46         glEnd,
#      47         glHint,
#      48         glLineStipple,
#      49         glLineWidth,
#      50         glPopMatrix,
#      51         glPushMatrix,
#      52         glRotatef,
#      53         glScalef,
#      54         glTranslatef,
#      55         gluOrtho2D,
#      56         glVertex2f,
#      57         glVertex3f,
#      58     )
#      59 except ImportError:
#      60     raise ImportError(
#      61         "Error occurred while running `from pyglet.gl import *`, HINT: make sure you have OpenGL installed. "
#      62         "On Ubuntu, you can run 'apt-get install python3-opengl'. If you're running on a server, you may need a "
#      63         "virtual frame buffer; something like this should work:"
#      64         "'xvfb-run -s \"-screen 0 1400x900x24\" python <your_script.py>'"
#      65     )
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/pyglet/gl/__init__.py:232
#     229 if not _is_pyglet_doc_run and 'pyglet.window' not in _sys.modules and _pyglet.options['shadow_window']:
#     230     # trickery is for circular import
#     231     _pyglet.gl = _sys.modules[__name__]
# --> 232     import pyglet.window
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/pyglet/window/__init__.py:1919
#    1917 if not _is_pyglet_doc_run:
#    1918     pyglet.window = sys.modules[__name__]
# -> 1919     gl._create_shadow_window()
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/pyglet/gl/__init__.py:206, in _create_shadow_window()
#     203     return
#     205 from pyglet.window import Window
# --> 206 _shadow_window = Window(width=1, height=1, visible=False)
#     207 _shadow_window.switch_to()
#     209 from pyglet import app
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/pyglet/window/xlib/__init__.py:171, in XlibWindow.__init__(self, *args, **kwargs)
#     168         else:
#     169             self._event_handlers[message] = func
# --> 171 super(XlibWindow, self).__init__(*args, **kwargs)
#     173 global _can_detect_autorepeat
#     174 if _can_detect_autorepeat is None:
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/pyglet/window/__init__.py:601, in BaseWindow.__init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, file_drops, display, screen, config, context, mode)
#     597 for template_config in [gl.Config(double_buffer=True, depth_size=24),
#     598                         gl.Config(double_buffer=True, depth_size=16),
#     599                         None]:
#     600     try:
# --> 601         config = screen.get_best_config(template_config)
#     602         break
#     603     except NoSuchConfigException:
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/pyglet/canvas/base.py:192, in Screen.get_best_config(self, template)
#     190             pass
#     191 else:
# --> 192     configs = self.get_matching_configs(template)
#     193 if not configs:
#     194     raise window.NoSuchConfigException()
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/pyglet/canvas/xlib.py:220, in XlibScreen.get_matching_configs(self, template)
#     218 def get_matching_configs(self, template):
#     219     canvas = XlibCanvas(self.display, None)
# --> 220     configs = template.match(canvas)
#     221     # XXX deprecate
#     222     for config in configs:
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/pyglet/gl/xlib.py:58, in XlibConfig.match(self, canvas)
#      55 x_screen = canvas.display.x_screen
#      57 info = glx_info.GLXInfo(x_display)
# ---> 58 have_13 = info.have_version(1, 3)
#      59 if have_13:
#      60     config_class = XlibCanvasConfig13
#
# File ~/miniconda3/envs/thesis_env/lib/python3.10/site-packages/pyglet/gl/glx_info.py:86, in GLXInfo.have_version(self, major, minor)
#      83     raise GLXInfoException('pyglet requires an X server with GLX')
#      85 server_version = self.get_server_version().split()[0]
# ---> 86 client_version = self.get_client_version().split()[0]
#      88 server = [int(i) for i in server_version.split('.')]
#      89 client = [int(i) for i in client_version.split('.')]
#
# IndexError: list index out of range
